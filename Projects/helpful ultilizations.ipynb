# %%
import inquirer
questions = [
  inquirer.List('size',
                message="What size do you need?",
                choices=['Jumbo', 'Large', 'Standard', 'Medium', 'Small', 'Micro'],
            ),
]
answers = inquirer.prompt(questions)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import inquirer
#       2 questions = [
#       3   inquirer.List('size',
#       4                 message="What size do you need?",
#       5                 choices=['Jumbo', 'Large', 'Standard', 'Medium', 'Small', 'Micro'],
#       6             ),
#       7 ]
#       8 answers = inquirer.prompt(questions)
#
# ModuleNotFoundError: No module named 'inquirer'

# %%
import inquirer

choice = inquirer.list_input("What choice?", choices=["1", "2", "3", "Other"])
if choice == "Other":
    result = inquirer.text("Enter text: ")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import inquirer
#       3 choice = inquirer.list_input("What choice?", choices=["1", "2", "3", "Other"])
#       4 if choice == "Other":
#
# ModuleNotFoundError: No module named 'inquirer'
