# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
def speedFind(vi,a,t):
    vf = vi + (a*t)
    return(vf)
print(speedFind(10,2,5))
# Out:
# 20

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def perfectnum(pn):
    sumpn = []
    for i in range(1, pn):
        if pn % i == 0:
            sumpn.append(i)
        else:
            continue
    return sum(sumpn) == pn

for num in range(1, 1001):
    if perfectnum(num):
        print(num)
# Out:
# 6
# 28
# 496

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pythagorean():
    for a in range(1, 101):
        for b in range(a, 101):
            for c in range(b, 101):
                if a**2 + b**2 == c**2:
                    print(f"a: {a}, b: {b}, c: {c}")

pythagorean()
# Out:
# a: 3, b: 4, c: 5
# a: 5, b: 12, c: 13
# a: 6, b: 8, c: 10
# a: 7, b: 24, c: 25
# a: 8, b: 15, c: 17
# a: 9, b: 12, c: 15
# a: 9, b: 40, c: 41
# a: 10, b: 24, c: 26
# a: 11, b: 60, c: 61
# a: 12, b: 16, c: 20
# a: 12, b: 35, c: 37
# a: 13, b: 84, c: 85
# a: 14, b: 48, c: 50
# a: 15, b: 20, c: 25
# a: 15, b: 36, c: 39
# a: 16, b: 30, c: 34
# a: 16, b: 63, c: 65
# a: 18, b: 24, c: 30
# a: 18, b: 80, c: 82
# a: 20, b: 21, c: 29
# a: 20, b: 48, c: 52
# a: 21, b: 28, c: 35
# a: 21, b: 72, c: 75
# a: 24, b: 32, c: 40
# a: 24, b: 45, c: 51
# a: 24, b: 70, c: 74
# a: 25, b: 60, c: 65
# a: 27, b: 36, c: 45
# a: 28, b: 45, c: 53
# a: 28, b: 96, c: 100
# a: 30, b: 40, c: 50
# a: 30, b: 72, c: 78
# a: 32, b: 60, c: 68
# a: 33, b: 44, c: 55
# a: 33, b: 56, c: 65
# a: 35, b: 84, c: 91
# a: 36, b: 48, c: 60
# a: 36, b: 77, c: 85
# a: 39, b: 52, c: 65
# a: 39, b: 80, c: 89
# a: 40, b: 42, c: 58
# a: 40, b: 75, c: 85
# a: 42, b: 56, c: 70
# a: 45, b: 60, c: 75
# a: 48, b: 55, c: 73
# a: 48, b: 64, c: 80
# a: 51, b: 68, c: 85
# a: 54, b: 72, c: 90
# a: 57, b: 76, c: 95
# a: 60, b: 63, c: 87
# a: 60, b: 80, c: 100
# a: 65, b: 72, c: 97

# %%
def pisagor_bulma() :
    pisagor_listesi =[]
    for i in range(1,101):
        for j in range(1,101):
            c = ( i**2 + j**2 )**0.5
            if (c == int(c)):
                pisagor_listesi.append((i,j,int(c)))
    return pisagor_listesi

for i in pisagor_bulma():
    print(i)
# Out:
# a = 3, b = 4, c = 5
# a = 4, b = 3, c = 5
# a = 5, b = 12, c = 13
# a = 6, b = 8, c = 10
# a = 7, b = 24, c = 25
# a = 8, b = 6, c = 10
# a = 8, b = 15, c = 17
# a = 9, b = 12, c = 15
# a = 9, b = 40, c = 41
# a = 10, b = 24, c = 26
# a = 11, b = 60, c = 61
# a = 12, b = 5, c = 13
# a = 12, b = 9, c = 15
# a = 12, b = 16, c = 20
# a = 12, b = 35, c = 37
# a = 13, b = 84, c = 85
# a = 14, b = 48, c = 50
# a = 15, b = 8, c = 17
# a = 15, b = 20, c = 25
# a = 15, b = 36, c = 39
# a = 16, b = 12, c = 20
# a = 16, b = 30, c = 34
# a = 16, b = 63, c = 65
# a = 18, b = 24, c = 30
# a = 18, b = 80, c = 82
# a = 20, b = 15, c = 25
# a = 20, b = 21, c = 29
# a = 20, b = 48, c = 52
# a = 20, b = 99, c = 101
# a = 21, b = 20, c = 29
# a = 21, b = 28, c = 35
# a = 21, b = 72, c = 75
# a = 24, b = 7, c = 25
# a = 24, b = 10, c = 26
# a = 24, b = 18, c = 30
# a = 24, b = 32, c = 40
# a = 24, b = 45, c = 51
# a = 24, b = 70, c = 74
# a = 25, b = 60, c = 65
# a = 27, b = 36, c = 45
# a = 28, b = 21, c = 35
# a = 28, b = 45, c = 53
# a = 28, b = 96, c = 100
# a = 30, b = 16, c = 34
# a = 30, b = 40, c = 50
# a = 30, b = 72, c = 78
# a = 32, b = 24, c = 40
# a = 32, b = 60, c = 68
# a = 33, b = 44, c = 55
# a = 33, b = 56, c = 65
# a = 35, b = 12, c = 37
# a = 35, b = 84, c = 91
# a = 36, b = 15, c = 39
# a = 36, b = 27, c = 45
# a = 36, b = 48, c = 60
# a = 36, b = 77, c = 85
# a = 39, b = 52, c = 65
# a = 39, b = 80, c = 89
# a = 40, b = 9, c = 41
# a = 40, b = 30, c = 50
# a = 40, b = 42, c = 58
# a = 40, b = 75, c = 85
# a = 40, b = 96, c = 104
# a = 42, b = 40, c = 58
# a = 42, b = 56, c = 70
# a = 44, b = 33, c = 55
# a = 45, b = 24, c = 51
# a = 45, b = 28, c = 53
# a = 45, b = 60, c = 75
# a = 48, b = 14, c = 50
# a = 48, b = 20, c = 52
# a = 48, b = 36, c = 60
# a = 48, b = 55, c = 73
# a = 48, b = 64, c = 80
# a = 48, b = 90, c = 102
# a = 51, b = 68, c = 85
# a = 52, b = 39, c = 65
# a = 54, b = 72, c = 90
# a = 55, b = 48, c = 73
# a = 56, b = 33, c = 65
# a = 56, b = 42, c = 70
# a = 56, b = 90, c = 106
# a = 57, b = 76, c = 95
# a = 60, b = 11, c = 61
# a = 60, b = 25, c = 65
# a = 60, b = 32, c = 68
# a = 60, b = 45, c = 75
# a = 60, b = 63, c = 87
# a = 60, b = 80, c = 100
# a = 60, b = 91, c = 109
# a = 63, b = 16, c = 65
# a = 63, b = 60, c = 87
# a = 63, b = 84, c = 105
# a = 64, b = 48, c = 80
# a = 65, b = 72, c = 97
# a = 66, b = 88, c = 110
# a = 68, b = 51, c = 85
# a = 69, b = 92, c = 115
# a = 70, b = 24, c = 74
# a = 72, b = 21, c = 75
# a = 72, b = 30, c = 78
# a = 72, b = 54, c = 90
# a = 72, b = 65, c = 97
# a = 72, b = 96, c = 120
# a = 75, b = 40, c = 85
# a = 75, b = 100, c = 125
# a = 76, b = 57, c = 95
# a = 77, b = 36, c = 85
# a = 80, b = 18, c = 82
# a = 80, b = 39, c = 89
# a = 80, b = 60, c = 100
# a = 80, b = 84, c = 116
# a = 84, b = 13, c = 85
# a = 84, b = 35, c = 91
# a = 84, b = 63, c = 105
# a = 84, b = 80, c = 116
# a = 88, b = 66, c = 110
# a = 90, b = 48, c = 102
# a = 90, b = 56, c = 106
# a = 91, b = 60, c = 109
# a = 92, b = 69, c = 115
# a = 96, b = 28, c = 100
# a = 96, b = 40, c = 104
# a = 96, b = 72, c = 120
# a = 99, b = 20, c = 101
# a = 100, b = 75, c = 125

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
def painting(wallHeight,wallWidth):
    area = wallHeight * wallWidth
    paint = 5
    import math
    print(math.ceil(area / 5))

painting(2,4)
# Out:
# 2

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
v = [] # vowels
c = [] # consonants

def vowcon(x):
    vowels = "aeiouAEIOU"
    for i in x:
        if i in vowels:
            v.append(i)
        else:
            c.append(i)
    num1 = len(v)
    num2 = len(c)
    print(f'The number of vowels are {num1}, and the number of consonants are {num2}')
    print(f'Vowels: {v}')
    print(f'Consonants: {c}')

vowcon("YetGen")
# Out:
# The number of vowels are 2, and the number of consonants are 4
# Vowels: ['e', 'e']
# Consonants: ['Y', 't', 'G', 'n']

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
l = [] # list
en = [] # list of even numbers
a = int(input("How many number do you want to add to the list: "))
for i in range(a):
    i = int(input("Give a number: "))
    l.append(i)
for b in l:
    if b % 2 == 0:
        en.append(b)

print(en)
# Out:
# [2, 4]

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %% [markdown]
# recursive function = kendi içinde fonksiyonu çağırmak

# %%
def sumnum(a,b):
    s = 0
    for i in range(a,b+1):
        s = s + i
    print(s)
sumnum(0,10)
# Out:
# 55
