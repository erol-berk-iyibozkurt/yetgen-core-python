# %% [markdown]
# # Problem 1
# ```test.txt``` dosyasındaki satır sayısını bularak ekrana yazdırınız.
#
#
#
# ```
# > Output
# Number of lines in the file:  6
#
# ```

# %%
with open("doc.txt","r",encoding= "utf-8") as f1:
    a = f1.readlines()
    print(len(a))
# Out:
# 5
