# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
name = input("Your name: ")
cell = input("Your cell:")
userData = {name : cell} 
print(userData, type(userData))

person = input("Give a name:")

if person in userData.keys():
    print(person + "is in our phone list" + userData[person])
# Out:
# {'Ali': '545456785878'} <class 'dict'>

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
employee = input("name of employee: ")
hometown = input("Your hometown:")
age = input("Your age is ")
position = input("You work as a/an ")
employeeData = {employee : {hometown, age, position}}
#0: City, 1: age, 2: title
print(employeeData)
# Out:
# {'ahmet': {'istanbul', '19', 'student'}}

# %%
person1 = input("name")
if person1 
print(employeeData[person1][0], employeeData[person1][1], employeeData[person1][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(employeeData[person][0], employeeData[person][1], employeeData[person][2])
#
# NameError: name 'person' is not defined

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
studentsName = input("Name: ")
grades = {}
grades["grade 1"] = input("Your first grade: ")
grades["grade 2"] = input("Your second grade: ")
grades["grade 3"] = input("Your third grade: ")
allData = {}
allData[studentsName] = grades
print(allData)
# Out:
# {'Mehmet': {'grade 1': '45', 'grade 2': '55', 'grade 3': '65'}}

# %%
ogrenciNotlari = {
    'Batuhan': [80,75,60],
    'Şule': [76,85,90],
    'Zeynep': [60,75,86]

}

# %% [markdown]
# # Problem 4

# %%
print("1-  'Bmw, Mercedes, Opel, Mazda' elemanlarına sahip bir liste oluşturunuz.")
vehicleBrands = ["Bmw","Mercedes","Opel","Mazda"]

print("2-  Liste Kaç elemanlıdır ?")
print(len(vehicleBrands))

print("3-  Listenin ilk ve son elemanı nedir ?")
print(vehicleBrands[0,-1])

print("4-  Mazda değerini Toyota ile değiştirin.")
vehicleBrands[3] = Toyota
print(vehicleBrands)

print("5-  Listenin -2 indeksindeki değer nedir ?")
print(vehicleBrands[-2])

print("6-  Listenin ilk 3 elemanını alın.")
print(vehicleBrands[:3])

print("7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.")
vehicleBrands(-2:0) = ("Toyota", "Renault")
print(vehicleBrands)

print("8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.")
vehicleBrands.add("Audi","Nissan")
print(vehicleBrands)

print("9- Listenin son elemanını silin.")
del(vehicleBrands(-1))

print("10- Liste elemanlarını tersten yazdırınız."")
vehicleBrands.reverse
print(vehicleBrands)

# %%
print("11- Aşağıdaki verileri bir liste içinde saklayınız.")

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
studentA = "Yiğit Bilgi 2010 (70,60,70)"
studentB = "Sena  Turan 1999 (80,80,70)"
studentC = "Ahmet Turan 1998 (80,70,90)"
students = [studentA.split(), studentB.split(),studentC.split()]

# %%
print("12- Liste elemanlarını ekrana yazdırınız.")  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]
print(names)
print(years)

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")
print(names)

# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0,"Sena")
print(names)

# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")

# 16-  "Ali" listenin bir elemanı mıdır ?
names.find("Ali")
names.count("Ali") #Bütün itemlara gider - index ilk gördüğüne gider
if names.index("Ali") != -1:
      print("This is ali")
else:
      print("not ali")

# 17-  Liste elemanlarını ters çevirin.
names.reverse()

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()
names.sort(reverse = True)
# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
cars = list(str("Chervolet","Dacia"))
print(cars)
cars = "Chevrolet,Daica"
cars.split()

# 21- years dizisinde kaç tane 1998 değeri vardır ?
years.find("1998")

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
carList = []
for car in carList:
      carList = input("First car brand:")
      carList = input("Second car brand:")
      carList = input("Third car brand:")
# Out:
# 12- Liste elemanlarını ekrana yazdırınız.
# ['Ali', 'Yağmur', 'Hakan', 'Deniz']
# [1998, 2000, 1998, 1987]
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 19
#      16 names.remove("Deniz")
#      18 # 16-  "Ali" listenin bir elemanı mıdır ?
# ---> 19 names.find("Ali")
#      20 names.count("Ali") #Bütün itemlara gider - index ilk gördüğüne gider
#      21 if names.index("Ali") != -1:
#
# AttributeError: 'list' object has no attribute 'find'

# %%
cars = cars

# %%
cars.extend(['Nissan','Yamaha'])
